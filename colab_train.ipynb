# %% [markdown]
# # Colab: Optional training run for Code-Only-LLM 100-150M
#
# Upload this project to Colab (or clone from repo). Mount Drive for checkpoints. Run cells below.

# %%
# Install deps
# !pip install -q torch transformers tokenizers datasets safetensors pyyaml tqdm accelerate
# Optional: mount Drive for checkpoints
# from google.colab import drive
# drive.mount("/content/drive")
# CHECKPOINT_DIR = "/content/drive/MyDrive/llm_plus_checkpoints"

# %%
# Small config for Colab (T4/L4): batch 2, seq 256
import os
os.chdir("/content/LLM+")  # adjust if project is elsewhere
# !python training/train.py --config training/config_train.yaml --checkpoint_dir checkpoints

# %% [markdown]
# # Giant-Killer 150M Code-Only LLM: Colab Training Iterate
#
# This notebook represents the intermediate testing loop for early iteration scaling down to ~50M parameters, compatible with Google Colab T4/L4 environments.

# %%
# !pip install torch transformers datasets tokenizers pyyaml tqdm
# !pip install accelerate bitsandbytes

# %%
# Plan §12: Colab optional für Zwischenläufe; Checkpoints auf Drive
import os
os.chdir("/content/LLM+")
# !python training/train.py --config training/config_train.yaml --checkpoint_dir checkpoints --max_steps 5000
